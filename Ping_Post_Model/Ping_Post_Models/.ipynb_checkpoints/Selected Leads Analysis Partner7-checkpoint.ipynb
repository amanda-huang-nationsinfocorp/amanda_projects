# %%
import snowflake.connector
from sqlalchemy import create_engine
from sqlalchemy import text
from snowflake.sqlalchemy import URL
from datetime import datetime, timedelta, timezone,date
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/amanda.huang/Downloads/partner_api_transaction.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
import json

# Convert JSON string to dict
df_parsed = df['raw_request_json'].apply(json.loads)

# Turn into columns
df_expanded = pd.json_normalize(df_parsed)

# Combine with original df if needed
df_final = pd.concat([df.drop(columns='raw_request_json'), df_expanded], axis=1)

# %%
df_final.columns
# Out:
# Index(['id', 'ping_id', 'jluvr', 'id_ad', 'id_brand', 'id_partner',
#        'partner_name', 'ping_group', 'raw_response_json', 'accepted',
#        'request_datetime', 'response_datetime', 'last_modified', 'income',
#        'lastName', 'driverState', 'purpose', 'postalCode', 'jobTitle',
#        'bankName', 'bankruptcy', 'mailing', 'directDeposit', 'frequency',
#        'driverLicense', 'company', 'military', 'accountLength', 'email',
#        'timeJob', 'aff', 'amount', 'creditScore', 'payDateNext', 'homePhone',
#        'accountType', 'locality', 'ipAddress', 'userAgent', 'accountNumber',
#        'timeAddress', 'accountABA', 'SSN', 'firstName', 'apiToken',
#        'termsAgreed', 'mobilePhone', 'streetAddress', 'homeOwner', 'dob',
#        'domain', 'minPrice', 'workPhone', 'incomeSource', 'timeAllowed',
#        'region', 'payDate'],
#       dtype='object')

# %%
df_final['dob'] = pd.to_datetime(df_final['dob'], errors='coerce').dt.date

# %%
df_final['income'] = pd.to_numeric(df_final['income'], errors='coerce')

# %%
df_final['amount'] = pd.to_numeric(df_final['amount'], errors='coerce')

# %%
def calculate_age(dob):
    if pd.isna(dob):
        return None
    today = date.today()
    age = today.year - dob.year
    if (today.month, today.day) < (dob.month, dob.day):
        age -= 1
    return age

df_final['age'] = df_final['dob'].apply(calculate_age)

# %%
df_final['age'] = df_final['dob'].apply(calculate_age)

# %%
def label_age_group(age):
    if age < 30:
        return '30 and under'
    elif 30 < age < 40:
        return '30-40'
    elif 40 < age < 50:
        return '40-50'
    elif 50 < age < 60:
        return '50-60'
    else:
        return '60+'

df_final['age_group'] = df_final['age'].apply(label_age_group)

# %%
def label_income_group(income):
    if income < 3000:
        return '3000 and under'
    elif 3000 < income < 4000:
        return '3000-4000'
    elif 4000 < income < 5000:
        return '4000-5000'
    elif 5000 < income < 6000:
        return '5000-6000'
    else:
        return '6000+'

df_final['income_group'] = df_final['income'].apply(label_income_group)

# %%
df_final['platform'] = df_final['userAgent'].str.extract(r'\(([^;]+);')

# %%
selected_email = ['nikkiavila3740@gmail.com','hippykisses0@gmail.com','gatormomma30@gmail.com','lcmartinezz73@gmail.com','jacsonthf4kp@yahoo.com','hhall1122@yahoo.com','sophiakennedy4@hotmail.com','jordan.rambo@gmail.com','andrea.wilson55@yahoo.com','vkm198@gmail.com']

# %%
df_selected_email = df_final[df_final['accepted'] == 1]

# %%
df_final = df_final[~df_final['accepted'].isin(selected_email)]

# %%
df_selected_email.groupby('age_group').count()/df_selected_email.groupby('age_group').count().sum()
# Out:
#                  id   ping_id     jluvr     id_ad  id_brand  id_partner  \
# age_group
# 30-40      0.310345  0.310345  0.310345  0.310345       NaN    0.310345
# 40-50      0.310345  0.310345  0.310345  0.310345       NaN    0.310345
# 50-60      0.155172  0.155172  0.155172  0.155172       NaN    0.155172
# 60+        0.224138  0.224138  0.224138  0.224138       NaN    0.224138
#
#            partner_name  ping_group  raw_response_json  accepted  \
# age_group
# 30-40          0.310345    0.310345           0.310345  0.310345
# 40-50          0.310345    0.310345           0.310345  0.310345
# 50-60          0.155172    0.155172           0.155172  0.155172
# 60+            0.224138    0.224138           0.224138  0.224138
#
#            request_datetime  response_datetime  last_modified    income  \
# age_group
# 30-40              0.310345           0.310345       0.310345  0.310345
# 40-50              0.310345           0.310345       0.310345  0.310345
# ...

# %%
df_final.groupby('age_group').count()/df_final.groupby('age_group').count().sum()
# Out:
#                     id   ping_id     jluvr     id_ad  id_brand  id_partner  \
# age_group
# 30 and under  0.003546  0.003546  0.003546  0.003546       0.0    0.003546
# 30-40         0.421986  0.421986  0.421986  0.421986       0.4    0.421986
# 40-50         0.329787  0.329787  0.329787  0.329787       0.0    0.329787
# 50-60         0.141844  0.141844  0.141844  0.141844       0.2    0.141844
# 60+           0.102837  0.102837  0.102837  0.102837       0.4    0.102837
#
#               partner_name  ping_group  raw_response_json  accepted  \
# age_group
# 30 and under      0.003546    0.003546           0.003559  0.003546
# 30-40             0.421986    0.421986           0.423488  0.421986
# 40-50             0.329787    0.329787           0.327402  0.329787
# 50-60             0.141844    0.141844           0.142349  0.141844
# 60+               0.102837    0.102837           0.103203  0.102837
#
#               request_datetime  response_datetime  last_modified    income  \
# ...

# %%
df_final.groupby('homeOwner').count()/df_final.groupby('homeOwner').count().sum()
# Out:
#                  id   ping_id     jluvr     id_ad  id_brand  id_partner  \
# homeOwner
# own        0.315603  0.315603  0.315603  0.315603       0.0    0.315603
# rent       0.684397  0.684397  0.684397  0.684397       1.0    0.684397
#
#            partner_name  ping_group  raw_response_json  accepted  \
# homeOwner
# own            0.315603    0.315603           0.316726  0.315603
# rent           0.684397    0.684397           0.683274  0.684397
#
#            request_datetime  response_datetime  last_modified    income  \
# homeOwner
# own                0.315603           0.316726       0.315603  0.316726
# rent               0.684397           0.683274       0.684397  0.683274
#
#            lastName  driverState   purpose  postalCode  jobTitle  bankName  \
# homeOwner
# own        0.316726     0.316726  0.315603    0.327206  0.316726  0.316726
# rent       0.683274     0.683274  0.684397    0.672794  0.683274  0.683274
#
# ...

# %%
df_selected_email.groupby('homeOwner').count()/df_selected_email.groupby('homeOwner').count().sum()
# Out:
#                 id  ping_id    jluvr    id_ad  id_brand  id_partner  \
# homeOwner
# own        0.37931  0.37931  0.37931  0.37931       NaN     0.37931
# rent       0.62069  0.62069  0.62069  0.62069       NaN     0.62069
#
#            partner_name  ping_group  raw_response_json  accepted  \
# homeOwner
# own             0.37931     0.37931            0.37931   0.37931
# rent            0.62069     0.62069            0.62069   0.62069
#
#            request_datetime  response_datetime  last_modified   income  \
# homeOwner
# own                 0.37931            0.37931        0.37931  0.37931
# rent                0.62069            0.62069        0.62069  0.62069
#
#            lastName  driverState  purpose  postalCode  jobTitle  bankName  \
# homeOwner
# own         0.37931      0.37931  0.37931     0.37931   0.37931   0.37931
# rent        0.62069      0.62069  0.62069     0.62069   0.62069   0.62069
#
# ...

# %%
df_final.groupby('income_group').count()/df_final.groupby('income_group').count().sum()
# Out:
#                       id   ping_id     jluvr     id_ad  id_brand  id_partner  \
# income_group
# 3000 and under  0.003546  0.003546  0.003546  0.003546       0.0    0.003546
# 3000-4000       0.351064  0.351064  0.351064  0.351064       0.6    0.351064
# 4000-5000       0.117021  0.117021  0.117021  0.117021       0.0    0.117021
# 5000-6000       0.067376  0.067376  0.067376  0.067376       0.2    0.067376
# 6000+           0.460993  0.460993  0.460993  0.460993       0.2    0.460993
#
#                 partner_name  ping_group  raw_response_json  accepted  \
# income_group
# 3000 and under      0.003546    0.003546           0.003559  0.003546
# 3000-4000           0.351064    0.351064           0.352313  0.351064
# 4000-5000           0.117021    0.117021           0.117438  0.117021
# 5000-6000           0.067376    0.067376           0.067616  0.067376
# 6000+               0.460993    0.460993           0.459075  0.460993
#
# ...

# %%
df_selected_email.groupby('income_group').count()/df_selected_email.groupby('income_group').count().sum()
# Out:
#                     id   ping_id     jluvr     id_ad  id_brand  id_partner  \
# income_group
# 3000-4000     0.327586  0.327586  0.327586  0.327586       NaN    0.327586
# 4000-5000     0.137931  0.137931  0.137931  0.137931       NaN    0.137931
# 5000-6000     0.034483  0.034483  0.034483  0.034483       NaN    0.034483
# 6000+         0.500000  0.500000  0.500000  0.500000       NaN    0.500000
#
#               partner_name  ping_group  raw_response_json  accepted  \
# income_group
# 3000-4000         0.327586    0.327586           0.327586  0.327586
# 4000-5000         0.137931    0.137931           0.137931  0.137931
# 5000-6000         0.034483    0.034483           0.034483  0.034483
# 6000+             0.500000    0.500000           0.500000  0.500000
#
#               request_datetime  response_datetime  last_modified    income  \
# income_group
# 3000-4000             0.327586           0.327586       0.327586  0.327586
# ...

# %%
df_final.groupby('platform').count()/df_final.groupby('platform').count().sum()
# Out:
#                        id   ping_id     jluvr     id_ad  id_brand  id_partner  \
# platform
# Linux            0.236641  0.236641  0.236641  0.236641       NaN    0.236641
# Macintosh        0.026718  0.026718  0.026718  0.026718       NaN    0.026718
# Windows NT 10.0  0.114504  0.114504  0.114504  0.114504       NaN    0.114504
# iPhone           0.622137  0.622137  0.622137  0.622137       NaN    0.622137
#
#                  partner_name  ping_group  raw_response_json  accepted  \
# platform
# Linux                0.236641    0.236641           0.237548  0.236641
# Macintosh            0.026718    0.026718           0.026820  0.026718
# Windows NT 10.0      0.114504    0.114504           0.114943  0.114504
# iPhone               0.622137    0.622137           0.620690  0.622137
#
#                  request_datetime  response_datetime  last_modified    income  \
# platform
# Linux                    0.236641           0.237548       0.236641  0.236641
# ...

# %%
df_selected_email.groupby('platform').count()/df_selected_email.groupby('platform').count().sum()
# Out:
#                        id   ping_id     jluvr     id_ad  id_brand  id_partner  \
# platform
# Linux            0.275862  0.275862  0.275862  0.275862       NaN    0.275862
# Macintosh        0.034483  0.034483  0.034483  0.034483       NaN    0.034483
# Windows NT 10.0  0.189655  0.189655  0.189655  0.189655       NaN    0.189655
# iPhone           0.500000  0.500000  0.500000  0.500000       NaN    0.500000
#
#                  partner_name  ping_group  raw_response_json  accepted  \
# platform
# Linux                0.275862    0.275862           0.275862  0.275862
# Macintosh            0.034483    0.034483           0.034483  0.034483
# Windows NT 10.0      0.189655    0.189655           0.189655  0.189655
# iPhone               0.500000    0.500000           0.500000  0.500000
#
#                  request_datetime  response_datetime  last_modified    income  \
# platform
# Linux                    0.275862           0.275862       0.275862  0.275862
# ...

# %%
df_selected_email.groupby('amount').count()/df_selected_email.groupby('amount').count().sum()
# Out:
#               id   ping_id     jluvr     id_ad  id_brand  id_partner  \
# amount
# 200.0   0.206897  0.206897  0.206897  0.206897       NaN    0.206897
# 300.0   0.155172  0.155172  0.155172  0.155172       NaN    0.155172
# 400.0   0.120690  0.120690  0.120690  0.120690       NaN    0.120690
# 450.0   0.017241  0.017241  0.017241  0.017241       NaN    0.017241
# 500.0   0.310345  0.310345  0.310345  0.310345       NaN    0.310345
# 600.0   0.120690  0.120690  0.120690  0.120690       NaN    0.120690
# 700.0   0.034483  0.034483  0.034483  0.034483       NaN    0.034483
# 2600.0  0.017241  0.017241  0.017241  0.017241       NaN    0.017241
# 3000.0  0.017241  0.017241  0.017241  0.017241       NaN    0.017241
#
#         partner_name  ping_group  raw_response_json  accepted  \
# amount
# 200.0       0.206897    0.206897           0.206897  0.206897
# 300.0       0.155172    0.155172           0.155172  0.155172
# 400.0       0.120690    0.120690           0.120690  0.120690
# ...

# %%
 df_final.groupby('region').count()/df_final.groupby('region').count().sum()
# Out:
#               id   ping_id     jluvr     id_ad  id_brand  id_partner  \
# region
# CA      0.213523  0.213523  0.213523  0.213523       0.2    0.213523
# DE      0.007117  0.007117  0.007117  0.007117       0.0    0.007117
# FL      0.085409  0.085409  0.085409  0.085409       0.0    0.085409
# HI      0.003559  0.003559  0.003559  0.003559       0.0    0.003559
# IA      0.010676  0.010676  0.010676  0.010676       0.0    0.010676
# ID      0.003559  0.003559  0.003559  0.003559       0.0    0.003559
# IN      0.017794  0.017794  0.017794  0.017794       0.0    0.017794
# KS      0.007117  0.007117  0.007117  0.007117       0.2    0.007117
# KY      0.010676  0.010676  0.010676  0.010676       0.0    0.010676
# LA      0.014235  0.014235  0.014235  0.014235       0.0    0.014235
# MI      0.074733  0.074733  0.074733  0.074733       0.0    0.074733
# MN      0.017794  0.017794  0.017794  0.017794       0.0    0.017794
# ...

# %%
df_selected_email.groupby('region').count()/df_selected_email.groupby('region').count().sum()
# Out:
#               id   ping_id     jluvr     id_ad  id_brand  id_partner  \
# region
# CA      0.172414  0.172414  0.172414  0.172414       NaN    0.172414
# FL      0.120690  0.120690  0.120690  0.120690       NaN    0.120690
# HI      0.017241  0.017241  0.017241  0.017241       NaN    0.017241
# IN      0.017241  0.017241  0.017241  0.017241       NaN    0.017241
# LA      0.017241  0.017241  0.017241  0.017241       NaN    0.017241
# MI      0.051724  0.051724  0.051724  0.051724       NaN    0.051724
# MN      0.017241  0.017241  0.017241  0.017241       NaN    0.017241
# MO      0.051724  0.051724  0.051724  0.051724       NaN    0.051724
# MS      0.051724  0.051724  0.051724  0.051724       NaN    0.051724
# NE      0.034483  0.034483  0.034483  0.034483       NaN    0.034483
# NM      0.034483  0.034483  0.034483  0.034483       NaN    0.034483
# SC      0.051724  0.051724  0.051724  0.051724       NaN    0.051724
# ...

# %%
df_selected_email[df_selected_email['region'] == 'FL']
# Out:
#        id                               ping_id  \
# 51   7133  e19c06b0-2062-4d86-a811-2ee9f2a0b710
# 110  6996  ddb1d5ef-0631-4c76-bb20-bc8a4ab870c5
# 134  6962  519b834c-b850-418c-8576-0df77d829416
# 153  6934  89f35fbb-04c6-4b92-bdde-3aefbc3a7eff
# 174  6908  b6b46e7b-5e6a-48e9-b192-d64b7f86c1c9
# 184  6870  8046b782-2818-428e-92ad-8bf5ebbb5359
# 231  6807  6b241917-6944-4f07-906d-026c6d1dbdc5
#
#                                     jluvr          id_ad  id_brand  \
# 51   e8bb9259-4aaf-4cce-b551-056241fcbbe6  CSRC941018000       NaN
# 110  f9f9efdc-30fe-474a-9084-1afdf0461989  CSRC941018000       NaN
# 134  85c038ee-6f70-4d22-8d0d-c2a0bd21bd74  CSRC941018000       NaN
# 153  dc381c6d-c0aa-42f3-9f00-e9473bf89dbd  CSRC941018000       NaN
# 174  7a412ceb-2256-4fd3-88c4-7f9b46c20be5  CSRC941018000       NaN
# 184  9e66c899-e122-4970-b13f-d2d5a3767796  CSRC941018000       NaN
# 231  4b792e45-10b5-49e0-8f2c-25b794d03a9d  CSRC941018000       NaN
#
# ...

# %%
# hfaui fhaie fer tfi iwery9 pqeirh guweaigiueg 7auie thfnhjkdbv auy fhuaf laf lwefuu lufhj gfhwae fle,af wyufj  fuwal fauhj
